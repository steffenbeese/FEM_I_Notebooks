# %%
import fem1d

# %%
model = fem1d.read_model_toml("./problem_stab.toml")
model.assembleGlobalMatrix()
model.solveSystem()

# %%
model.computeDisplacement()
# Out:
# (array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#          5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ]),
#  array([4.76190476e-04, 4.23280423e-04, 3.70370370e-04, 3.17460317e-04,
#         2.64550265e-04, 2.11640212e-04, 1.58730159e-04, 1.05820106e-04,
#         5.29100529e-05, 0.00000000e+00]))

# %%
model.plotMesh(deformed=True)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)
