# %%
pip install jupyter-copilot
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 5.4 MB/s eta 0:00:005.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %system jupyter labextension list
# Out:
# ['JupyterLab v4.4.6',
#  '/home/steffen/anaconda3/envs/rise/share/jupyter/labextensions',
#  '        jupyter_copilot v0.1.5 \x1benabled\x1b \x1bOK\x1b (python, jupyter_copilot)',
#  '        jupyterlab_pygments v0.3.0 \x1benabled\x1b \x1bOK\x1b (python, jupyterlab_pygments)',
#  '        jupyterlab-rise v0.43.1 \x1benabled\x1b \x1bOK\x1b (python, jupyterlab_rise)',
#  '        jupyterlab-jupytext v1.4.3 \x1benabled\x1b \x1bOK\x1b (python, jupytext)',
#  '        jupyter-matplotlib v0.11.7 \x1benabled\x1b \x1bOK\x1b',
#  '        anywidget v0.9.18 \x1benabled\x1b \x1bOK\x1b',
#  '        @jans-code/jupyterlab_rise_metadata_form v1.0.1 \x1benabled\x1b \x1bOK\x1b (python, jupyterlab_rise_metadata_form)',
#  '        @jupyter-widgets/jupyterlab-manager v5.0.13 \x1benabled\x1b \x1bOK\x1b (python, jupyterlab_widgets)',
#  '        @jupyterlab/mathjax3-extension v4.3.0 \x1benabled\x1b \x1b X\x1b (python, jupyterlab-mathjax3)',
#  '',
#  '',
# ...
